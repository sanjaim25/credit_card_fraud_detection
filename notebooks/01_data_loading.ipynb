# %% [markdown]
# # 01 - Data Loading
# Load the raw `creditcard.csv` dataset and perform initial inspection.

# %%
# 01 - Data Loading
# Load the raw `creditcard.csv` dataset and perform initial inspection.

import pandas as pd
import numpy as np
import yaml
import sys

# Add src folder
sys.path.append("../src")

from data_preprocessing import load_data, check_missing, remove_duplicates, get_class_stats

# -----------------------------
# Load configuration
# -----------------------------
with open("../configs/config.yaml", "r") as f:
    config = yaml.safe_load(f)

DATA_PATH = config["paths"]["raw_data"]

df = load_data(DATA_PATH)
# Out:
#  Dataset loaded successfully
#  Shape: 284807 rows × 31 columns

# %%
# Save cleaned dataset
df.to_csv(config["paths"]["processed_data"], index=False)

print("Clean dataset saved to:", config["paths"]["processed_data"])
# Out:
# Clean dataset saved to: ../data/processed/creditcard_clean.csv

# %%
print("\nDataset Information\n")
df.info()
# Out:
# Dataset Information
#
# <class 'pandas.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
# ...

# %%
# Save cleaned dataset
df.to_csv(config["paths"]["processed_data"], index=False)

print("Processed dataset saved!")
# Out:
# Processed dataset saved!

# %%
print("\nMissing Values Per Column\n")
check_missing(df)
# Out:
# Missing Values Per Column
#
#
#  Missing Values Per Column
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64
#
#  Total Missing Values: 0
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
print("\nFraud vs Legitimate Transactions\n")
get_class_stats(df)
# Out:
# Fraud vs Legitimate Transactions
#
#
#  Fraud Statistics
# {'legitimate_transactions': 284315, 'fraud_transactions': 492, 'fraud_percentage': 0.1727}
# {'legitimate_transactions': 284315,
#  'fraud_transactions': 492,
#  'fraud_percentage': 0.1727}

# %%
df = remove_duplicates(df)
print("New Shape:", df.shape)
# Out:
#  Removed 1081 duplicate rows
# New Shape: (283726, 31)
